# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir("DS3000 - FP")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-c7b814ba5cc0> in <module>()
#       1 import os
# ----> 2 os.chdir("DS3000 - FP")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'DS3000 - FP'

# %%
# !ls
# Out:
# 'ACES ASB.gdoc'
# 'Colab Notebooks'
# 'Copy of Discrete Grades -  Calculator.gsheet'
# 'COVID CNN project'
#  CVT
#  Final_Resume_10:8.pdf
# 'Final_Resume_10:8 - Sam Zlota.pdf'
# 'Final_Resume (1).docx'
# 'Google Earth'
#  Misc.
#  model_NASNet.json
# 'OSCCR LETTER.gdoc'
# 'plerdge stuff.gdoc'
# 'project ct-scans'
# 'Sam Zlota Resume A.pdf'
#  SANDBOX.gdoc
#  School
# 'Untitled document (1).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document.gdoc'
# 'Untitled drawing (1).gdraw'
# 'Untitled drawing (2).gdraw'
# 'Untitled drawing.gdraw'
# 'Untitled form.gform'
# 'Untitled presentation.gslides'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet (2).gsheet'
# 'Untitled spreadsheet.gsheet'
